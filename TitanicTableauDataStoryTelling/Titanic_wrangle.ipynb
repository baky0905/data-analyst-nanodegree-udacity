# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Cleaning titanic dataset so it is readily usable with Tableau

# %% [markdown]
# Data Dictionary
#
# Variable	Definition	Key
#
# survival	Survival	0 = No, 1 = Yes
# pclass	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# sex	Sex
# Age	Age in years
# sibsp	# of siblings / spouses aboard the Titanic
# parch	# of parents / children aboard the Titanic
# ticket	Ticket number
# fare	Passenger fare
# cabin	Cabin number
# embarked	Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton
# Variable Notes
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# #### Load data

# %%
titanic = pd.read_csv("titanic-data2.csv")

# %%
df = pd.DataFrame.copy(titanic)

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Improve column names

# %%
df.columns = ["PassengerID","Destiny","PassengerClass","Name","Gender","Age","#SiblingsSpouses","#ParentsChildren","TicketNumber","PassengerFareUSD","CabinNumber","PortEmbarked"]

# %%
df.head()
# Out:
#    PassengerID   Destiny  PassengerClass  \
# 0            1      Died               3
# 1            2  Survived               1
# 2            3  Survived               3
# 3            4  Survived               1
# 4            5      Died               3
#
#                                                 Name  Gender   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#    #SiblingsSpouses  #ParentsChildren      TicketNumber  PassengerFareUSD  \
# 0                 1                 0         A/5 21171            7.2500
# 1                 1                 0          PC 17599           71.2833
# 2                 0                 0  STON/O2. 3101282            7.9250
# 3                 1                 0            113803           53.1000
# 4                 0                 0            373450            8.0500
#
#   CabinNumber PortEmbarked
# 0         NaN            S
# 1         C85            C
# 2         NaN            S
# 3        C123            S
# 4         NaN            S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerID         891 non-null int64
# Destiny             891 non-null object
# PassengerClass      891 non-null int64
# Name                891 non-null object
# Gender              891 non-null object
# Age                 714 non-null float64
# #SiblingsSpouses    891 non-null int64
# #ParentsChildren    891 non-null int64
# TicketNumber        891 non-null object
# PassengerFareUSD    891 non-null float64
# CabinNumber         204 non-null object
# PortEmbarked        889 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.6+ KB

# %% [markdown]
# #### Mapping out few of the columns I am planning to utilize to a more descriptive values

# %%
survived_dict = {0: "Died", 1: "Survived"}

# %%
df.replace({"Survived" : survived_dict},inplace = True)

# %%
port_of_embarkment = {"C" : "Cherbourg", "Q" : "Queenstown", "S" : "Southampton"}

# %%
df.replace({"PortEmbarked" : port_of_embarkment}, inplace = True)

# %%
passenger_class_dict = {1 : "Upper", 2 : "Middle", 3 : "Lower"}

# %%
df.replace({"PassengerClass" : passenger_class_dict}, inplace = True)

# %%
df
# Out:
#      PassengerID   Destiny PassengerClass  \
# 0              1      Died          Lower
# 1              2  Survived          Upper
# 2              3  Survived          Lower
# 3              4  Survived          Upper
# 4              5      Died          Lower
# 5              6      Died          Lower
# 6              7      Died          Upper
# 7              8      Died          Lower
# 8              9  Survived          Lower
# 9             10  Survived         Middle
# 10            11  Survived          Lower
# 11            12  Survived          Upper
# 12            13      Died          Lower
# 13            14      Died          Lower
# 14            15      Died          Lower
# 15            16  Survived         Middle
# 16            17      Died          Lower
# 17            18  Survived         Middle
# 18            19      Died          Lower
# 19            20  Survived          Lower
# 20            21      Died         Middle
# 21            22  Survived         Middle
# 22            23  Survived          Lower
# 23            24  Survived          Upper
# 24            25      Died          Lower
# 25            26  Survived          Lower
# 26            27      Died          Lower
# 27            28      Died          Upper
# 28            29  Survived          Lower
# 29            30      Died          Lower
# ..           ...       ...            ...
# 861          862      Died         Middle
# 862          863  Survived          Upper
# 863          864      Died          Lower
# 864          865      Died         Middle
# 865          866  Survived         Middle
# 866          867  Survived         Middle
# 867          868      Died          Upper
# 868          869      Died          Lower
# 869          870  Survived          Lower
# 870          871      Died          Lower
# 871          872  Survived          Upper
# 872          873      Died          Upper
# 873          874      Died          Lower
# 874          875  Survived         Middle
# 875          876  Survived          Lower
# 876          877      Died          Lower
# 877          878      Died          Lower
# 878          879      Died          Lower
# 879          880  Survived          Upper
# 880          881  Survived         Middle
# 881          882      Died          Lower
# 882          883      Died          Lower
# 883          884      Died         Middle
# 884          885      Died          Lower
# 885          886      Died          Lower
# 886          887      Died         Middle
# 887          888  Survived          Upper
# 888          889      Died          Lower
# 889          890  Survived          Upper
# 890          891      Died          Lower
#
#                                                   Name  Gender   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# 5                                     Moran, Mr. James    male   NaN
# 6                              McCarthy, Mr. Timothy J    male  54.0
# 7                       Palsson, Master. Gosta Leonard    male   2.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0
# 12                      Saundercock, Mr. William Henry    male  20.0
# 13                         Andersson, Mr. Anders Johan    male  39.0
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16                                Rice, Master. Eugene    male   2.0
# 17                        Williams, Mr. Charles Eugene    male   NaN
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 19                             Masselmani, Mrs. Fatima  female   NaN
# 20                                Fynney, Mr. Joseph J    male  35.0
# 21                               Beesley, Mr. Lawrence    male  34.0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0
# 23                        Sloper, Mr. William Thompson    male  28.0
# 24                       Palsson, Miss. Torborg Danira  female   8.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# 26                             Emir, Mr. Farred Chehab    male   NaN
# 27                      Fortune, Mr. Charles Alexander    male  19.0
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN
# 29                                 Todoroff, Mr. Lalio    male   NaN
# ..                                                 ...     ...   ...
# 861                        Giles, Mr. Frederick Edward    male  21.0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 864                             Gill, Mr. John William    male  24.0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0
# 866                       Duran y More, Miss. Asuncion  female  27.0
# 867               Roebling, Mr. Washington Augustus II    male  31.0
# 868                        van Melkebeke, Mr. Philemon    male   NaN
# 869                    Johnson, Master. Harold Theodor    male   4.0
# 870                                  Balkic, Mr. Cerin    male  26.0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 872                           Carlsson, Mr. Frans Olof    male  33.0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0
# 877                               Petroff, Mr. Nedelio    male  19.0
# 878                                 Laleff, Mr. Kristo    male   NaN
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 881                                 Markun, Mr. Johann    male  33.0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0
# 883                      Banfield, Mr. Frederick James    male  28.0
# 884                             Sutehall, Mr. Henry Jr    male  25.0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#      #SiblingsSpouses  #ParentsChildren      TicketNumber  PassengerFareUSD  \
# 0                   1                 0         A/5 21171            7.2500
# 1                   1                 0          PC 17599           71.2833
# 2                   0                 0  STON/O2. 3101282            7.9250
# 3                   1                 0            113803           53.1000
# 4                   0                 0            373450            8.0500
# 5                   0                 0            330877            8.4583
# 6                   0                 0             17463           51.8625
# 7                   3                 1            349909           21.0750
# 8                   0                 2            347742           11.1333
# 9                   1                 0            237736           30.0708
# 10                  1                 1           PP 9549           16.7000
# 11                  0                 0            113783           26.5500
# 12                  0                 0         A/5. 2151            8.0500
# 13                  1                 5            347082           31.2750
# 14                  0                 0            350406            7.8542
# 15                  0                 0            248706           16.0000
# 16                  4                 1            382652           29.1250
# 17                  0                 0            244373           13.0000
# 18                  1                 0            345763           18.0000
# 19                  0                 0              2649            7.2250
# 20                  0                 0            239865           26.0000
# 21                  0                 0            248698           13.0000
# 22                  0                 0            330923            8.0292
# 23                  0                 0            113788           35.5000
# 24                  3                 1            349909           21.0750
# 25                  1                 5            347077           31.3875
# 26                  0                 0              2631            7.2250
# 27                  3                 2             19950          263.0000
# 28                  0                 0            330959            7.8792
# 29                  0                 0            349216            7.8958
# ..                ...               ...               ...               ...
# 861                 1                 0             28134           11.5000
# 862                 0                 0             17466           25.9292
# 863                 8                 2          CA. 2343           69.5500
# 864                 0                 0            233866           13.0000
# 865                 0                 0            236852           13.0000
# 866                 1                 0     SC/PARIS 2149           13.8583
# 867                 0                 0          PC 17590           50.4958
# 868                 0                 0            345777            9.5000
# 869                 1                 1            347742           11.1333
# 870                 0                 0            349248            7.8958
# 871                 1                 1             11751           52.5542
# 872                 0                 0               695            5.0000
# 873                 0                 0            345765            9.0000
# 874                 1                 0         P/PP 3381           24.0000
# 875                 0                 0              2667            7.2250
# 876                 0                 0              7534            9.8458
# 877                 0                 0            349212            7.8958
# 878                 0                 0            349217            7.8958
# 879                 0                 1             11767           83.1583
# 880                 0                 1            230433           26.0000
# 881                 0                 0            349257            7.8958
# 882                 0                 0              7552           10.5167
# 883                 0                 0  C.A./SOTON 34068           10.5000
# 884                 0                 0   SOTON/OQ 392076            7.0500
# 885                 0                 5            382652           29.1250
# 886                 0                 0            211536           13.0000
# 887                 0                 0            112053           30.0000
# 888                 1                 2        W./C. 6607           23.4500
# 889                 0                 0            111369           30.0000
# 890                 0                 0            370376            7.7500
#
#      CabinNumber PortEmbarked
# 0            NaN  Southampton
# 1            C85    Cherbourg
# 2            NaN  Southampton
# 3           C123  Southampton
# 4            NaN  Southampton
# 5            NaN   Queenstown
# 6            E46  Southampton
# 7            NaN  Southampton
# 8            NaN  Southampton
# 9            NaN    Cherbourg
# 10            G6  Southampton
# 11          C103  Southampton
# 12           NaN  Southampton
# 13           NaN  Southampton
# 14           NaN  Southampton
# 15           NaN  Southampton
# 16           NaN   Queenstown
# 17           NaN  Southampton
# 18           NaN  Southampton
# 19           NaN    Cherbourg
# 20           NaN  Southampton
# 21           D56  Southampton
# 22           NaN   Queenstown
# 23            A6  Southampton
# 24           NaN  Southampton
# 25           NaN  Southampton
# 26           NaN    Cherbourg
# 27   C23 C25 C27  Southampton
# 28           NaN   Queenstown
# 29           NaN  Southampton
# ..           ...          ...
# 861          NaN  Southampton
# 862          D17  Southampton
# 863          NaN  Southampton
# 864          NaN  Southampton
# 865          NaN  Southampton
# 866          NaN    Cherbourg
# 867          A24  Southampton
# 868          NaN  Southampton
# 869          NaN  Southampton
# 870          NaN  Southampton
# 871          D35  Southampton
# 872  B51 B53 B55  Southampton
# 873          NaN  Southampton
# 874          NaN    Cherbourg
# 875          NaN    Cherbourg
# 876          NaN  Southampton
# 877          NaN  Southampton
# 878          NaN  Southampton
# 879          C50    Cherbourg
# 880          NaN  Southampton
# 881          NaN  Southampton
# 882          NaN  Southampton
# 883          NaN  Southampton
# 884          NaN  Southampton
# 885          NaN   Queenstown
# 886          NaN  Southampton
# 887          B42  Southampton
# 888          NaN  Southampton
# 889         C148    Cherbourg
# 890          NaN   Queenstown
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Getting an overview

# %%
df["Destiny"].value_counts()
# Out:
# Died        549
# Survived    342
# Name: Destiny, dtype: int64

# %%
columns = list(df.columns)

# %%
df["PassengerClass"].value_counts()
# Out:
# Lower     491
# Upper     216
# Middle    184
# Name: PassengerClass, dtype: int64

# %%
sum(df["Name"].duplicated())
# Out:
# 0

# %%
df["Gender"].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["#SiblingsSpouses"].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: #SiblingsSpouses, dtype: int64

# %%
df["#ParentsChildren"].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: #ParentsChildren, dtype: int64

# %%
df["TicketNumber"].value_counts()
# Out:
# CA. 2343             7
# 347082               7
# 1601                 7
# 347088               6
# 3101295              6
# CA 2144              6
# 382652               5
# S.O.C. 14879         5
# 349909               4
# 113760               4
# 4133                 4
# W./C. 6608           4
# 17421                4
# PC 17757             4
# 2666                 4
# 113781               4
# LINE                 4
# 347077               4
# 19950                4
# PC 17572             3
# C.A. 31921           3
# SC/Paris 2123        3
# 239853               3
# PC 17755             3
# 24160                3
# 29106                3
# 363291               3
# 230080               3
# PC 17760             3
# 35273                3
#                     ..
# 29108                1
# 2926                 1
# 5727                 1
# 364512               1
# 113509               1
# SC/Paris 2163        1
# 347083               1
# A/5 3536             1
# 11771                1
# 349204               1
# STON/O 2. 3101285    1
# 113059               1
# 234818               1
# 2223                 1
# 312991               1
# 28228                1
# 36865                1
# 113794               1
# A/5. 13032           1
# 349239               1
# 2689                 1
# STON/O 2. 3101273    1
# 2677                 1
# 347060               1
# 336439               1
# 347073               1
# 349224               1
# 315088               1
# 374746               1
# PC 17609             1
# Name: TicketNumber, Length: 681, dtype: int64

# %%
df["PassengerFareUSD"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: PassengerFareUSD, dtype: float64

# %%
df["CabinNumber"].value_counts()
# Out:
# G6                 4
# C23 C25 C27        4
# B96 B98            4
# E101               3
# F2                 3
# F33                3
# C22 C26            3
# D                  3
# D35                2
# B49                2
# B77                2
# C83                2
# E8                 2
# E25                2
# E67                2
# D20                2
# B18                2
# C123               2
# E24                2
# B28                2
# C126               2
# B51 B53 B55        2
# E33                2
# E44                2
# B57 B59 B63 B66    2
# D33                2
# B5                 2
# C68                2
# D36                2
# B20                2
#                   ..
# B80                1
# C128               1
# C70                1
# B79                1
# A31                1
# B38                1
# C45                1
# C85                1
# A6                 1
# T                  1
# E10                1
# D11                1
# D47                1
# D28                1
# A14                1
# A10                1
# A34                1
# D49                1
# C54                1
# A19                1
# E36                1
# C99                1
# B101               1
# D50                1
# B71                1
# D10 D12            1
# E38                1
# A24                1
# D48                1
# E63                1
# Name: CabinNumber, Length: 147, dtype: int64

# %%
df["PortEmbarked"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: PortEmbarked, dtype: int64

# %% [markdown]
# ### EXPORT

# %%
df.to_csv("titanic_cleaned.csv")
